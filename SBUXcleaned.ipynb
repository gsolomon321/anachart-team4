# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # SBUX

# %%
dataset = "Retail_Dataset(Sheet1).csv"
df = pd.read_csv("Retail_Dataset(Sheet1).csv", encoding="latin1")
df.head()
# Out:
#   Row        date         company_Name ticker    broker      analytst  \
# 0   1   6/12/2020  Lululemon Athletica   LULU  BARCLAYS  ADRIENNE YIH
# 1   2    7/9/2020  Lululemon Athletica   LULU  BARCLAYS  ADRIENNE YIH
# 2   3    9/9/2020  Lululemon Athletica   LULU  BARCLAYS  ADRIENNE YIH
# 3   4  12/11/2020  Lululemon Athletica   LULU  BARCLAYS  ADRIENNE YIH
# 4   5   3/31/2022  Lululemon Athletica   LULU  BARCLAYS  ADRIENNE YIH
#
#                    rating_before                   rating_after  \
# 0                                 OVERWEIGHT
# 1                      NOT FOUND                      NOT FOUND
# 2                                 OVERWEIGHT
# 3                                 OVERWEIGHT
# 4                                 OVERWEIGHT
#
#   price_target_before  price_target_after
# 0                 350                 347
# 1                 NaN
# 2                 347                 382
# 3                 382                 410
# ...

# %%
cols = ["rating_before", "rating_after", "price_target_before", "price_target_after"]
df = df[df["ticker"] == "SBUX"].copy()
df[cols] = df[cols].replace(["NOT FOUND", "", " "], np.nan)
df[cols] = df[cols].apply(lambda col: col.map(lambda x: np.nan if isinstance(x, str) and x.strip() == "" else x))
sb_clean = df.dropna(subset=cols)
sb_clean.head(20)
# Out:
#      Row        date    company_Name ticker          broker  \
# 202  203   4/17/2023  Starbucks Corp   SBUX             NaN
# 203  204   7/17/2023  Starbucks Corp   SBUX             NaN
# 204  205    8/2/2023  Starbucks Corp   SBUX             NaN
# 205  206  10/11/2023  Starbucks Corp   SBUX             NaN
# 206  207   7/12/2024  Starbucks Corp   SBUX  MORGAN STANLEY
# 207  208   7/31/2024  Starbucks Corp   SBUX  MORGAN STANLEY
# 218  219   6/14/2023  Starbucks Corp   SBUX             NaN
# 219  220  10/19/2023  Starbucks Corp   SBUX             NaN
# 220  221   1/19/2024  Starbucks Corp   SBUX             NaN
# 221  222   7/16/2024  Starbucks Corp   SBUX             NaN
# 222  223   8/14/2024  Starbucks Corp   SBUX             NaN
# 242  243   9/21/2021  Starbucks Corp   SBUX          STIFEL
# 243  244   11/1/2021  Starbucks Corp   SBUX          STIFEL
# 244  245    5/1/2024  Starbucks Corp   SBUX          STIFEL
# 245  246   8/14/2024  Starbucks Corp   SBUX          STIFEL
# ...

# %%
sb_clean = sb_clean.rename(columns={"date" : "Date", "broker" : "Broker", "company_Name" : "Company Name", "ticker" : "Ticker", "analytst": "Analyst", 
                                    "rating_before" : "Rating Before", "rating_after" : "Rating After", "price_target_before" : "Price Target Before", 
                                    "price_target_after" : "Price Target After"})
cols_to_title = ["Broker", "Analyst", "Rating Before", "Rating After"]
for col in cols_to_title:
    sb_clean[col] = sb_clean[col].str.title()

sb_clean["Date"] = pd.to_datetime(sb_clean["Date"], errors="coerce")
sb_clean = sb_clean.sort_values(by="Date")
sb_clean.head(30)
# Out:
#      Row       Date    Company Name Ticker               Broker  \
# 689  690 2012-07-05  Starbucks Corp   SBUX        Piper Sandler
# 595  596 2014-07-25  Starbucks Corp   SBUX                  Ubs
# 694  695 2014-11-28  Starbucks Corp   SBUX        Piper Sandler
# 593  594 2015-01-23  Starbucks Corp   SBUX                  Ubs
# 277  278 2015-01-23  Starbucks Corp   SBUX                  Rbc
# 699  700 2015-02-10  Starbucks Corp   SBUX        Piper Sandler
# 708  709 2015-02-25  Starbucks Corp   SBUX        Piper Sandler
# 582  583 2015-03-19  Starbucks Corp   SBUX        Goldman Sachs
# 701  702 2015-04-10  Starbucks Corp   SBUX        Piper Sandler
# 592  593 2015-04-24  Starbucks Corp   SBUX                  Ubs
# 692  693 2015-06-25  Starbucks Corp   SBUX        Piper Sandler
# 278  279 2015-07-16  Starbucks Corp   SBUX                  Rbc
# 594  595 2015-07-24  Starbucks Corp   SBUX                  Ubs
# 702  703 2015-10-30  Starbucks Corp   SBUX        Piper Sandler
# ...

# %%
sb_clean.to_csv("SBUXcleaned1.csv", index=False)
